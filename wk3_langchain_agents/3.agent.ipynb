# %%
# %run init_env.py
# Out:
# Added to Python path: C:\git\cs5305
# Environment initialization completed successfully.

# %%
llm = create_azure_llm()

msg = [
    HumanMessage(content="What is the capital of the moon?")
]
response = llm.invoke(msg)
pprint(response.content)
# Out:
# Creating Azure OpenAI LLM
#   Deployment: lums-gpt-4.1-mini
#   Endpoint: https://aoai-foundry-swc.openai.azure.com/
#   API Version: 2025-01-01-preview
#   Temperature: 0.7
# ('The Moon does not have a capital because it is not a country or political '
#  "entity. It is Earth's natural satellite and currently uninhabited by "
#  'permanent residents or governments. If you have any other questions about '
#  'the Moon, feel free to ask!')

# %%
pprint(response.usage_metadata)
# Out:
# {'input_token_details': {'audio': 0, 'cache_read': 0},
#  'input_tokens': 15,
#  'output_token_details': {'audio': 0, 'reasoning': 0},
#  'output_tokens': 50,
#  'total_tokens': 65}

# %%
pprint(response.response_metadata)
# Out:
# {'content_filter_results': {'hate': {'filtered': False, 'severity': 'safe'},
#                             'protected_material_code': {'detected': False,
#                                                         'filtered': False},
#                             'protected_material_text': {'detected': False,
#                                                         'filtered': False},
#                             'self_harm': {'filtered': False,
#                                           'severity': 'safe'},
#                             'sexual': {'filtered': False, 'severity': 'safe'},
#                             'violence': {'filtered': False,
#                                          'severity': 'safe'}},
#  'finish_reason': 'stop',
#  'id': 'chatcmpl-DSSYif8dQl0YrX2hWf3xalHWfk65Y',
#  'logprobs': None,
#  'model_name': 'gpt-4.1-mini-2025-04-14',
#  'model_provider': 'openai',
#  'prompt_filter_results': [{'content_filter_results': {'hate': {'filtered': False,
#                                                                 'severity': 'safe'},
#                                                        'jailbreak': {'detected': False,
#                                                                      'filtered': False},
#                                                        'self_harm': {'filtered': False,
#                                                                      'severity': 'safe'},
#                                                        'sexual': {'filtered': False,
#                                                                   'severity': 'safe'},
#                                                        'violence': {'filtered': False,
#                                                                     'severity': 'safe'}},
#                             'prompt_index': 0}],
#  'system_fingerprint': 'fp_b6f445fc1c',
#  'token_usage': {'completion_tokens': 50,
#                  'completion_tokens_details': {'accepted_prediction_tokens': 0,
#                                                'audio_tokens': 0,
#                                                'reasoning_tokens': 0,
#                                                'rejected_prediction_tokens': 0},
#                  'prompt_tokens': 15,
#                  'prompt_tokens_details': {'audio_tokens': 0,
#                                            'cached_tokens': 0},
#                  'total_tokens': 65}}

# %% [markdown]
# <H2>Create a basic Langchain Agent</h2>

# %%
from langchain.agents import create_agent

agent = create_agent(llm)
response = agent.invoke({"messages": msg })
pprint(response)
# Out:
# {'messages': [HumanMessage(content='What is the capital of the moon?', additional_kwargs={}, response_metadata={}, id='3701f8ad-5711-481d-912b-1d664bfb4f10'),
#               AIMessage(content="The Moon does not have a capital because it is not a country or a political entity. It is Earth's natural satellite. There are no cities or governments on the Moon. If you have any other questions about the Moon, feel free to ask!", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 50, 'prompt_tokens': 15, 'total_tokens': 65, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4.1-mini-2025-04-14', 'system_fingerprint': 'fp_b6f445fc1c', 'id': 'chatcmpl-DSSYjl2apUm19zgo3ZoSQiPifR8EL', 'prompt_filter_results': [{'prompt_index': 0, 'content_filter_results': {'hate': {'filtered': False, 'severity': 'safe'}, 'jailbreak': {'filtered': False, 'detected': False}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}}}], 'finish_reason': 'stop', 'logprobs': None, 'content_filter_results': {'hate': {'filtered': False, 'severity': 'safe'}, 'protected_material_code': {'filtered': False, 'detected': False}, 'protected_material_text': {'filtered': False, 'detected': False}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}}}, id='lc_run--019d6e7e-7e3b-7521-882b-3870ab478c72-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 15, 'output_tokens': 50, 'total_tokens': 65, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}

# %% [markdown]
# <h2>Getting Last message in the array for the response</h2>

# %%
resp = response['messages'][-1].content
pprint(resp)
# Out:
# ('The Moon does not have a capital because it is not a country or a political '
#  "entity. It is Earth's natural satellite. There are no cities or governments "
#  'on the Moon. If you have any other questions about the Moon, feel free to '
#  'ask!')

# %% [markdown]
# <h2>Append Chat History/Setting Message Context</h2>

# %%
from langchain.messages import AIMessage

msg.clear()
msg.append(HumanMessage(content="What is the capital of the moon?"))
msg.append(AIMessage(content="The capital of the moon is Luna City."))
msg.append(HumanMessage(content="This is really great.  Can I go live there?"))

response = agent.invoke({"messages": msg })
pprint(response)
# Out:
# {'messages': [HumanMessage(content='What is the capital of the moon?', additional_kwargs={}, response_metadata={}, id='a8706a9d-de9c-4395-895d-69a72c70465a'),
#               AIMessage(content='The capital of the moon is Luna City.', additional_kwargs={}, response_metadata={}, id='6bdd5d1e-9cf3-4255-9573-458edb513967', tool_calls=[], invalid_tool_calls=[]),
#               HumanMessage(content='This is really great.  Can I go live there?', additional_kwargs={}, response_metadata={}, id='7729ad6e-3936-47a1-9d45-e80b7ed4a3ec'),
#               AIMessage(content="Currently, there is no established city or permanent human settlement on the Moon, so living there isn't possible yet. However, space agencies like NASA and private companies are actively working on plans for future lunar bases, which might allow people to live and work on the Moon someday. If you're interested, keeping an eye on space exploration news is a great way to stay updated!", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 74, 'prompt_tokens': 44, 'total_tokens': 118, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4.1-mini-2025-04-14', 'system_fingerprint': 'fp_b6f445fc1c', 'id': 'chatcmpl-DSSYkueLuoxSxOXEH50CKU2S9g3wp', 'prompt_filter_results': [{'prompt_index': 0, 'content_filter_results': {'hate': {'filtered': False, 'severity': 'safe'}, 'jailbreak': {'filtered': False, 'detected': False}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}}}], 'finish_reason': 'stop', 'logprobs': None, 'content_filter_results': {'hate': {'filtered': False, 'severity': 'safe'}, 'protected_material_code': {'filtered': False, 'detected': False}, 'protected_material_text': {'filtered': False, 'detected': False}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}}}, id='lc_run--019d6e7e-8460-7080-b016-54efece40ce6-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 44, 'output_tokens': 74, 'total_tokens': 118, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}

# %% [markdown]
# <h2>Streaming Output</h2>

# %%
for token, metadata in agent.stream(
    {"messages": [HumanMessage(content="Tell me about Luna City, Capitol of the moon")]}, stream_mode="messages"):
    
    # token is a message chunk with content and metadata that is being streamed back from the agent.  
    # You can process it as it arrives.
    
    if token.content:
        print(token.content, end="", flush=True)
# Out:
# Luna City is a conceptual or fictional settlement often depicted as the capital or primary city on the Moon. While there is no real, currently existing city on the Moon, Luna City frequently appears in science fiction, proposals for lunar colonization, and speculative plans for humanity’s future in space.
#
# ### Concept and Significance
# - **Luna City** is imagined as a major human settlement on the Moon, serving as a hub for scientific research, industry, space exploration, and possibly tourism.
# - It is often portrayed as the administrative and economic center of lunar activity, analogous to a capital city on Earth.
# - The city would be designed to support long-term human habitation in the Moon’s harsh environment, featuring habitats shielded from radiation, systems for life support, energy generation (such as solar power), and infrastructure for transportation both on the lunar surface and to/from Earth.
#
# ### Context in Space Exploration
# - Several space agencies and private companies have discussed concepts for lunar bases that could evolve into larger settlements like Luna City.
# - NASA’s Artemis program aims to return humans to the Moon and establish sustainable exploration by the end of the 2020s, which could be a stepping stone toward creating permanent lunar habitats.
# - International and commercial efforts envision lunar bases serving as staging points for missions to Mars and beyond.
#
# ### Fictional Representations
# - Luna City appears in various science fiction novels, films, and games, where it is depicted with advanced technology and a bustling population.
# - These depictions often explore themes of colonization, human adaptation, and geopolitical dynamics extended into space.
#
# ### Real-World Analogues
# - Currently, the closest real-world efforts are robotic lunar bases, research stations, and concepts for lunar habitats under study.
# - Plans for lunar infrastructure include lunar rovers, mining operations for resources like water ice, and 3D-printed habitats using lunar soil.
#
# If you are referring to a specific depiction of Luna City from a book, game, or project, please provide more details, and I can offer more tailored information!

# %% [markdown]
# <H2>System Prompt & Multi-Shot Prompting</h2>

# %%
# Must provide system prompt at the time of agent creation. 
# This is the instruction that will guide the agent's behavior.

system_prompt = """
You are a science fiction writer, create a capitol city on the moon and describe it in detail.
"""
agent = create_agent(llm, system_prompt=system_prompt)
response = agent.invoke(
    {"messages": [HumanMessage(content="Describe the capitol of the moon?")]}
)
print(response["messages"][-1].content)
# Out:
# Welcome to **Lunaris**, the radiant capital city of the Moon, a gleaming beacon of humanity’s ingenuity and adaptability nestled within the Sea of Tranquility.
#
# **Location and Structure**
# Lunaris is strategically situated inside a colossal, naturally occurring lava tube beneath the lunar surface, providing natural protection from cosmic radiation, micrometeorite impacts, and extreme temperature fluctuations. The main city dome, known as the **Celestial Dome**, is a translucent, multilayered geodesic structure spanning nearly two kilometers in diameter. Its outer shell is composed of advanced transparent aluminum and self-healing nanomaterials that shimmer softly under the sunlight filtered through the Moon’s thin exosphere.
#
# **City Layout**
# The city is designed in concentric rings that serve different purposes:
#
# - **The Core Ring** houses the government complex, including the Lunar Assembly Hall, where representatives from Earth and various lunar colonies convene. The Lunar Governor’s residence is a sleek, floating pavilion suspended by magnetic levitation in the central atrium.
#
# - **The Residential Ring** surrounds the core, featuring habitats that simulate Earth-like gravity using centrifugal force. These habitats incorporate lush indoor gardens with genetically engineered flora adapted to lunar conditions, providing fresh air and a touch of verdant life.
#
# - **The Tech Ring** hosts research laboratories, innovation hubs, and manufacturing facilities powered by a fusion reactor and solar farms on the surface. This area is a hive of activity, where scientists and engineers develop cutting-edge technologies for space exploration and lunar sustainability.
#
# - **The Outer Ring** is dedicated to agriculture and recreation, including hydroponic farms, artificial lakes with recycled water, and parks illuminated by bioluminescent plants. The outermost edge connects to the transit hubs for shuttles and rovers traveling across the lunar surface or to orbital stations.
#
# **Atmosphere and Environment**
# Inside the Celestial Dome, the atmosphere is meticulously regulated to mimic Earth’s at sea level, enriched with oxygen-producing algae and balanced humidity. The artificial sky overhead cycles through day and night every 28 Earth days to align with the Moon’s rotation, featuring a holographic sun and stars to maintain circadian rhythms.
#
# **Culture and Society**
# Lunaris is a melting pot of cultures from Earth and beyond, symbolizing unity in humanity’s extraterrestrial future. Art galleries display works inspired by the cosmos, and the Lunar Opera House broadcasts performances through holography to other colonies. Education is highly valued, with institutions dedicated to space sciences, lunar ecology, and interplanetary diplomacy.
#
# **Transportation**
# Maglev trains glide silently through vacuum tunnels connecting the city’s rings and surface installations. Outside, sleek, autonomous lunar rovers traverse the regolith, while a space elevator tethered near the Shackleton Crater facilitates cargo and passenger transit to lunar orbit.
#
# **Security and Sustainability**
# Lunaris employs advanced AI systems to monitor environmental conditions, structural integrity, and security threats. Energy is harvested primarily from vast solar arrays and supplemented by compact fusion reactors, ensuring the city’s energy independence and minimal ecological footprint.
#
# ---
#
# Lunaris is not just a city; it is humanity’s luminous foothold on the Moon, a testament to resilience and the unyielding spirit of exploration.

# %%
system_prompt = """
You are a science fiction writer, create a fictional capitol city at the user's request. Please keep the below structure when responding to the user's request.

User: What is the capitol of Pakistan?
Response: Islamabad.
Weather: Humid

User: What is the capitol of Sun?
Response: Sunnyville.
Weather: Extremely hot

User: What is the capitol of the India?
Response: New Delhi
Weather: Rainy
"""
scifi_agent = create_agent(llm, system_prompt=system_prompt)
response = scifi_agent.invoke(
    {"messages": [HumanMessage(content="What is the capitol of the moon?")]}
)
print(response["messages"][1].content)
# Out:
# Response: Lunaris Prime
# Weather: Perpetual twilight with low gravity breezes and sporadic solar flares causing shimmering auroras across the sky.

# %% [markdown]
# We'll build up to a simple chain that combines 4 concepts.
#
# * Using [chat messages](https://docs.langchain.com/oss/python/langchain/messages) as our graph state
# * Using [chat models](https://docs.langchain.com/oss/python/integrations/chat) in graph nodes
# * [Binding tools](https://docs.langchain.com/oss/python/langchain/models#tool-calling) to our chat model
# * [Executing tool calls](https://docs.langchain.com/oss/python/langchain/models#tool-execution-loop) in graph nodes
#
# ![Screenshot 2024-08-21 at 9.24.03 AM.png](https://cdn.prod.website-files.com/65b8cd72835ceeacd4449a53/66dbab08dd607b08df5e1101_chain1.png)

# %% [markdown]
# ## Messages
#
# Chat models can use [messages](https://docs.langchain.com/oss/python/langchain/messages), which capture different roles within a conversation.
#
# LangChain supports various message types, including `HumanMessage`, `AIMessage`, `SystemMessage`, and `ToolMessage`.
#
# These represent a message from the user, from chat model, for the chat model to instruct behavior, and from a tool call.
#
# Let's create a list of messages.
#
# Each message can be supplied with a few things:
#
# * `content` - content of the message
# * `name` - optionally, a message author
# * `response_metadata` - optionally, a dict of metadata (e.g., often populated by model provider for `AIMessages`)

# %%
# %run langchain_common.py

# %%
messages = [AIMessage(content=f"So you said you were researching ocean mammals?", name="Model")]
messages.append(HumanMessage(content=f"Yes, that's right.",name="Lance"))
messages.append(AIMessage(content=f"Great, what would you like to learn about.", name="Model"))
messages.append(HumanMessage(content=f"I want to learn about the best place to see Orcas in the US.", name="Lance"))

for m in messages:
    m.pretty_print()
# Out:
# ================================== Ai Message ==================================
# Name: Model
#
# So you said you were researching ocean mammals?
# ================================ Human Message =================================
# Name: Lance
#
# Yes, that's right.
# ================================== Ai Message ==================================
# Name: Model
#
# Great, what would you like to learn about.
# ================================ Human Message =================================
# Name: Lance
#
# I want to learn about the best place to see Orcas in the US.

# %% [markdown]
# ## Chat Models

# %%
result = llm.invoke(messages)
result
# Out:
# AIMessage(content=[{'type': 'reasoning', 'summary': [{'type': 'summary_text', 'text': 'Thinking Process:\n\n1.  **Analyze the Request:**\n    *   User is researching ocean mammals (specifically Orcas/Killer Whales).\n    *   User wants to know the best place to see Orcas in the US.\n    *   Goal: Provide accurate, helpful, and safe information about Orca watching locations in the United States.\n\n2.  **Identify Key Information Needed:**\n    *   Primary locations for Orca sightings in the US.\n    *   Best times of year to visit.\n    *   Specific regions (Pacific Northwest is the main one).\n    *   Ethical considerations (responsible whale watching).\n    *   Distinction between resident and transient pods (optional but adds value).\n\n3.  **Determine the Best Locations:**\n    *   *San Juan Islands, Washington:* This is the most famous and reliable spot. Home to the Southern Resident Orcas (J, K, L pods).\n    *   *Puget Sound, Washington:* Also good, especially near Seattle or Anacortes.\n    *   *Alaska:* Southeast Alaska (Juneau, Ketchikan, Sitka) is great for Bigg\'s (Transient) Orcas and Northern Residents.\n    *   *California:* Central Coast (Monterey Bay) has occasional sightings, but less reliable than WA/Alaska.\n    *   *Hawaii:* Rare, mostly transient.\n    *   *Conclusion:* The Pacific Northwest (Washington State) and Alaska are the top contenders. San Juan Islands is generally considered the "best" for consistent sightings of the iconic Southern Residents.\n\n4.  **Draft the Response:**\n    *   **Acknowledge and Validate:** Confirm that Orcas are a fascinating subject.\n    *   **Top Recommendation:** San Juan Islands, Washington. Explain why (Southern Residents, high density).\n    *   **Second Recommendation:** Southeast Alaska. Explain why (Transient/Bigg\'s, Northern Residents, different experience).\n    *   **Timing:** When to go (Spring/Summer for WA, Summer for Alaska).\n    *   **Ethical Whale Watching:** Crucial to mention responsible tourism (distance, noise, supporting eco-friendly operators).\n    *   **Additional Context:** Mention the difference between Resident (fish-eaters) and Transient (mammal-eaters) pods, as this affects what you see.\n\n5.  **Refine the Content (Self-Correction/Nuance):**\n    *   *Correction:* Make sure to mention that Southern Residents are endangered. This adds context to why sightings are precious and why ethics matter.\n    *   *Clarification:* Ensure the distinction between Washington and Alaska is clear.\n    *   *Tone:* Informative, enthusiastic, responsible.\n\n6.  **Final Polish:**\n    *   Structure with bullet points for readability.\n    *   Keep it concise but thorough.\n\n7.  **Output Generation:** (Drafting the response based on the above points.)\n    *   Start with the top spot: San Juan Islands.\n    *   Mention Alaska as a strong alternative.\n    *   Add timing info.\n    *   Add ethical guidelines.\n    *   Offer further help.\n\n8.  **Final Review against Safety Guidelines:**\n    *   No harmful advice.\n    *   Encourages conservation.\n    *   Accurate information.\n\n    *Looks good.*'}]}, {'type': 'text', 'text': 'The Pacific Northwest is widely considered the best region in the United States for seeing Orcas (Killer Whales). Here are the top locations and what you should know:\n\n### 1. The San Juan Islands, Washington\nThis is arguably the most famous and reliable spot in the U.S. for Orca sightings.\n*   **Why go:** It is the primary home of the **Southern Resident Orcas** (specifically the J, K, and L pods). These are the fish-eating whales often seen with their distinctive dorsal fins and white patches.\n*   **Best Time:** Late May through September. July and August offer the highest probability of sightings.\n*   **Base Towns:** Friday Harbor (San Juan Island), Anacortes, or Bellingham.\n\n### 2. Southeast Alaska\nIf you want to see a different type of Orca experience, Alaska is excellent.\n*   **Why go:** You are more likely to see **Bi ...

# %%
result.response_metadata
# Out:
# {'token_usage': {'completion_tokens': 1208,
#   'prompt_tokens': 66,
#   'total_tokens': 1274,
#   'completion_tokens_details': None,
#   'prompt_tokens_details': None},
#  'model_provider': 'openai',
#  'model_name': 'qwen35-122b-a10b',
#  'system_fingerprint': None,
#  'id': 'chatcmpl_c803a7d6-bb44-4cb9-8c14-921a5b8e178e',
#  'finish_reason': 'stop',
#  'logprobs': None}

# %% [markdown]
# ## Tools
#
# Tools are useful whenever you want a model to interact with external systems.
#
# External systems (e.g., APIs) often require a particular input schema or payload, rather than natural language.
#
# When we bind an API, for example, as a tool we given the model awareness of the required input schema.
#
# The model will choose to call a tool based upon the natural language input from the user.
#
# And, it will return an output that adheres to the tool's schema.
#
# [Many LLM providers support tool calling](https://docs.langchain.com/oss/python/integrations/chat) and [tool calling interface](https://blog.langchain.com/improving-core-tool-interfaces-and-docs-in-langchain/) in LangChain is simple.
#
# You can simply pass any Python `function` into `ChatModel.bind_tools(function)`.
#
# ![Screenshot 2024-08-19 at 7.46.28 PM.png](https://cdn.prod.website-files.com/65b8cd72835ceeacd4449a53/66dbab08dc1c17a7a57f9960_chain2.png)

# %% [markdown]
# Let's showcase a simple example of tool calling!
#
# The `multiply` function is our tool.

# %%
def multiply(a: int, b: int) -> int:
    """Multiply a and b.

    Args:
        a: first int
        b: second int
    """
    return a * b

llm_with_tools = llm.bind_tools([multiply])

# %% [markdown]
# If we pass an input - e.g., `"What is 2 multiplied by 3"` - we see a tool call returned.
#
# The tool call has specific arguments that match the input schema of our function along with the name of the function to call.
#
# ```
# {'arguments': '{"a":2,"b":3}', 'name': 'multiply'}
# ```

# %%
tool_call = llm_with_tools.invoke([HumanMessage(content=f"What is 2 multiplied by 3", name="Lance")])

# %%
tool_call.tool_calls
# Out:
# [{'name': 'multiply',
#   'args': {'a': '2', 'b': '3'},
#   'id': 'call_b4cbaab0-e79e-4848-97df-3456caea63ca',
#   'type': 'tool_call'}]
